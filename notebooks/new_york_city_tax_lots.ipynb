# %%
# !wget https://s-media.nyc.gov/agencies/dcp/assets/files/zip/data-tools/bytes/nyc_mappluto_24v1_fgdb.zip -O /tmp/nyc_mappluto_24v1_fgdb.zip
# !unzip -o /tmp/nyc_mappluto_24v1_fgdb.zip -d ~/data/nyc_mappluto_24v1_fgdb
# Out:
# --2024-03-29 09:20:40--  https://s-media.nyc.gov/agencies/dcp/assets/files/zip/data-tools/bytes/nyc_mappluto_24v1_fgdb.zip
# Resolving s-media.nyc.gov (s-media.nyc.gov)... 23.7.120.107
# Connecting to s-media.nyc.gov (s-media.nyc.gov)|23.7.120.107|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 141280001 (135M) [application/zip]
# Saving to: ‘/tmp/nyc_mappluto_24v1_fgdb.zip’
#
# /tmp/nyc_mappluto_2 100%[===================>] 134.73M  9.96MB/s    in 14s
#
# 2024-03-29 09:20:55 (9.31 MB/s) - ‘/tmp/nyc_mappluto_24v1_fgdb.zip’ saved [141280001/141280001]
#
# Archive:  /tmp/nyc_mappluto_24v1_fgdb.zip
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000001.freelist
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000001.gdbtable
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000001.gdbtablx
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000002.gdbtable
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000002.gdbtablx
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000003.gdbtable
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000003.gdbtablx
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000004.freelist
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000004.gdbtable
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000004.gdbtablx
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000005.gdbtable
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000005.gdbtablx
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000006.FDO_OriginID.atx
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000006.gdbindexes
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000006.gdbtable
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000006.gdbtablx
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000007.gdbtable
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000007.gdbtablx
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000009.freelist
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000009.gdbindexes
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000009.gdbtable
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000009.gdbtablx
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a00000009.spx
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a0000000a.gdbindexes
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a0000000a.gdbtable
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/a0000000a.gdbtablx
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/gdb
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb/timestamps
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/pluto_datadictionary.pdf
#   inflating: /Users/me/data/nyc_mappluto_24v1_fgdb/pluto_readme.pdf

# %% [markdown]
# # Load MapPLUTO data
#
# Takes ~13 minutes

# %%
import geopandas as gpd

file_path = '/Users/me/data/nyc_mappluto_24v1_fgdb/MapPLUTO24v1.gdb'
gdf = gpd.read_file(file_path)

# %%
gdf
# Out:
#        Borough  Block  Lot     CD  BCT2020    BCTCB2020 CT2010 CB2010  \
# 0           MN      1   10  101.0  1000500  10005000003      5   1000
# 1           MN      1  201  101.0  1000100  10001001000      1   1000
# 2           MN      2    1  101.0  1000900  10009001022      9   1025
# 3           MN      3   10  101.0  1031900  10319001006    319   1003
# 4           MN     10   23  101.0  1000900  10009001023      9   1026
# ...        ...    ...  ...    ...      ...          ...    ...    ...
# 856808      SI   8050   37  503.0  5024800  50248001014    248   1016
# 856809      SI   8050   50  503.0  5024800  50248001014    248   1016
# 856810      SI   8050   55  503.0  5024800  50248001014    248   1016
# 856811      SI   8050   56  503.0  5024800  50248001014    248   1016
# 856812      SI   8050   60  503.0  5024800  50248001014    248   1016
#
#        SchoolDist  Council  ...  FIRM07_FLAG PFIRM15_FLAG  Version  DCPEdited  \
# 0              02      1.0  ...            1            1     24v1       None
# 1              02      1.0  ...         None            1     24v1       None
# 2              02      1.0  ...            1            1     24v1          t
# 3              02      1.0  ...            1            1     24v1       None
# 4              02      1.0  ...            1            1     24v1       None
# ...           ...      ...  ...          ...          ...      ...        ...
# 856808         31     51.0  ...         None         None     24v1       None
# 856809         31     51.0  ...         None         None     24v1       None
# 856810         31     51.0  ...         None         None     24v1       None
# 856811         31     51.0  ...         None         None     24v1       None
# 856812         31     51.0  ...         None         None     24v1       None
#
#          Latitude  Longitude Notes Shape_Leng    Shape_Area  \
# 0       40.688766 -74.018682  None        0.0  7.478663e+06
# 1       40.698188 -74.041329  None        0.0  1.148538e+06
# 2       40.700369 -74.012911  None        0.0  1.008251e+05
# 3       40.700918 -74.014444  None        0.0  4.216466e+04
# 4       40.703808 -74.012757  None        0.0  2.051657e+04
# ...           ...        ...   ...        ...           ...
# 856808  40.507801 -74.251802  None        0.0  9.977568e+03
# 856809  40.508139 -74.251512  None        0.0  5.566174e+03
# 856810  40.508318 -74.251307  None        0.0  1.183376e+02
# 856811  40.508362 -74.251257  None        0.0  4.872917e+03
# 856812  40.508533 -74.251060  None        0.0  6.641693e+03
#
#                                                  geometry
# 0       MULTIPOLYGON (((980898.728 191409.779, 980881....
# 1       MULTIPOLYGON (((973648.065 193711.894, 973525....
# 2       MULTIPOLYGON (((980609.550 194220.422, 980608....
# 3       MULTIPOLYGON (((980198.105 194743.552, 980217....
# 4       MULTIPOLYGON (((980806.238 195679.849, 980810....
# ...                                                   ...
# 856808  MULTIPOLYGON (((914296.753 124363.477, 914214....
# 856809  MULTIPOLYGON (((914321.023 124460.350, 914256....
# 856810  MULTIPOLYGON (((914417.632 124539.857, 914416....
# 856811  MULTIPOLYGON (((914318.219 124604.403, 914338....
# 856812  MULTIPOLYGON (((914383.304 124709.774, 914517....
#
# [856813 rows x 95 columns]

# %%
gdf.plot(figsize=(10,10))
# Out:
# <Axes: >
